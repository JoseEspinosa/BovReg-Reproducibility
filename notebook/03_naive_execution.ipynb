# %% [markdown]
# # Run pipeline with bash (You will need to install salmon, fastQC and multiQC first)

# %%
import os, shutil
pwd = os.getcwd()
os.getcwd()
pipeline_folder = "rnaseq-nf" 
work_dir = pwd + "/../" + pipeline_folder
os.chdir(work_dir)
os.getcwd()
# Out:
# '/home/jespinosa/git/BovReg-Reproducibility/rnaseq-nf'

# %%
# !salmon index --threads 1 -t ./data/ggal/ggal_1_48850000_49020000.Ggal71.500bpflank.fa -i index
# Out:
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# [2020-01-17 16:47:28.586] [jLog] [info] building index
# out : index
# [2020-01-17 16:47:28.586] [puff::index::jointLog] [info] Running fixFasta
#
# [Step 1 of 4] : counting k-mers
#
# [2020-01-17 16:47:28.590] [puff::index::jointLog] [info] Replaced 0 non-ATCG nucleotides
# [2020-01-17 16:47:28.590] [puff::index::jointLog] [info] Clipped poly-A tails from 0 transcripts
# wrote 1 cleaned references
# seqHash 256 : c7b06752fa0748ecfa05ab97e8460b69c408b6d5fedf9de3d0d53b05570cf942
# seqHash 512 : ed859a805ddc0e6805be16dea7160060c1ecf1853f01fe24e64779390dd0b4aa157dab4d3e6234e9f7a1a80cd74df05454259b325624f601a0f86ea508550a8e
# nameHash 256 : 6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d49c01e52ddb7875b4b
# nameHash 512 : 4dff4ea340f0a823f15d3f4f01ab62eae0e5da579ccb851f8db9dfe84c58b2b37b89903a740e1ee172da793a6e79d560e5f7f9bd058a12a280433ed6fa46510a
# [2020-01-17 16:47:28.590] [puff::index::jointLog] [info] Filter size not provided; estimating from number of distinct k-mers
# [2020-01-17 16:47:28.592] [puff::index::jointLog] [info] ntHll estimated 147846 distinct k-mers, setting filter size to 2^22
# Threads = 1
# Vertex length = 31
# Hash functions = 5
# Filter size = 4194304
# Capacity = 2
# Files:
# index/ref_k31_fixed.fa
# --------------------------------------------------------------------------------
# Round 0, 0:4194304
# Pass	Filling	Filtering
# 1	0	0
# 2	0	0
# True junctions count = 7
# False junctions count = 236
# Hash table size = 243
# Candidate marks count = 250
# --------------------------------------------------------------------------------
# Reallocating bifurcations time: 0
# True marks count: 16
# Edges construction time: 0
# --------------------------------------------------------------------------------
# Distinct junctions = 7
#
# approximateContigTotalLength: 92130
# counters:
# 1 0 0 0
# contig count: 14 element count: 171333 complex nodes: 1
# size: 171333
# # of ones in rank vector: 13
# size: 171333
# [2020-01-17 16:47:28.678] [puff::index::jointLog] [info] Setting the index/BinaryGfa directory index
# size = 171333
# -----------------------------------------
# | Loading contigs | Time = 20.268 us
# -----------------------------------------
# size = 171333
# -----------------------------------------
# | Loading contig boundaries | Time = 10.715 us
# -----------------------------------------
# Number of ones: 13
# Number of ones per inventory item: 512
# Inventory entries filled: 1
# [2020-01-17 16:47:28.678] [puff::index::jointLog] [info] Done wrapping the rank vector with a rank9sel structure.
# [2020-01-17 16:47:28.678] [puff::index::jointLog] [info] contig count for validation: 13
# [2020-01-17 16:47:28.678] [puff::index::jointLog] [info] Total # of Contigs : 13
# [2020-01-17 16:47:28.678] [puff::index::jointLog] [info] Total # of numerical Contigs : 13
# [2020-01-17 16:47:28.678] [puff::index::jointLog] [info]
# Total # of segments we have position for : 13
# [2020-01-17 16:47:28.679] [puff::index::jointLog] [info] total contig vec entries 17
# [2020-01-17 16:47:28.679] [puff::index::jointLog] [info] bits per offset entry 5
# [2020-01-17 16:47:28.679] [puff::index::jointLog] [info] there were 1  equivalence classes
# [2020-01-17 16:47:28.679] [puff::index::jointLog] [info] # segments = 13
# [2020-01-17 16:47:28.679] [puff::index::jointLog] [info] total length = 171,333
# [2020-01-17 16:47:28.679] [puff::index::jointLog] [info] Reading the reference files ...
# [2020-01-17 16:47:28.680] [puff::index::jointLog] [info] positional integer width = 18
# [2020-01-17 16:47:28.680] [puff::index::jointLog] [info] seqSize = 171,333
# [2020-01-17 16:47:28.680] [puff::index::jointLog] [info] rankSize = 171,333
# [2020-01-17 16:47:28.680] [puff::index::jointLog] [info] edgeVecSize = 0
# [2020-01-17 16:47:28.680] [puff::index::jointLog] [info] num keys = 170,943
# for info, total work write each  : 2.331    total work inram from level 3 : 4.322  total work raw : 25.000
# [Building BooPHF]  100  %   elapsed:   0 min 0  sec   remaining:   0 min 0  sec
# Bitarray          901696  bits (100.00 %)   (array + ranks )
# final hash             0  bits (0.00 %) (nb in final hash 0)
# [2020-01-17 16:47:28.693] [puff::index::jointLog] [info] mphf size = 0.107491 MB
# [2020-01-17 16:47:28.693] [puff::index::jointLog] [info] chunk size = 171,333
# [2020-01-17 16:47:28.693] [puff::index::jointLog] [info] chunk 0 = [0, 171,303)
# [2020-01-17 16:47:28.701] [puff::index::jointLog] [info] finished populating pos vector
# [2020-01-17 16:47:28.701] [puff::index::jointLog] [info] writing index components
# [2020-01-17 16:47:28.701] [puff::index::jointLog] [info] finished writing dense pufferfish index
# [2020-01-17 16:47:28.701] [jLog] [info] done building index

# %%
# !salmon quant --threads 1 --libType=U -i index -1 ./data/ggal/ggal_gut_1.fq -2 ./data/ggal/ggal_gut_2.fq  -o results_salmon
# !rm -rf index
# Out:
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# ### salmon (mapping-based) v1.0.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ threads ] => { 1 }
# ### [ libType ] => { U }
# ### [ index ] => { index }
# ### [ mates1 ] => { ./data/ggal/ggal_gut_1.fq }
# ### [ mates2 ] => { ./data/ggal/ggal_gut_2.fq }
# ### [ output ] => { results_salmon }
# Logs will be written to results_salmon/logs
# [2020-01-17 16:47:29.930] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2020-01-17 16:47:29.930] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2020-01-17 16:47:29.930] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2020-01-17 16:47:29.930] [jointLog] [info] parsing read library format
# [2020-01-17 16:47:29.930] [jointLog] [info] There is 1 library.
# -----------------------------------------
# | Loading contig table | Time = 11.652 us
# -----------------------------------------
# size = 14
# -----------------------------------------
# | Loading contig offsets | Time = 18.315 us
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 4.739 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 52.308 us
# -----------------------------------------
# size = 171333
# Number of ones: 13
# Number of ones per inventory item: 512
# Inventory entries filled: 1
# -----------------------------------------
# | Loading contig boundaries | Time = 248.26 us
# -----------------------------------------
# size = 171333
# -----------------------------------------
# | Loading sequence | Time = 27.144 us
# -----------------------------------------
# size = 170943
# -----------------------------------------
# | Loading positions | Time = 63.44 us
# -----------------------------------------
# size = 171001
# -----------------------------------------
# | Loading reference sequence | Time = 23.572 us
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 5.067 us
# -----------------------------------------
#
#
#
#
# [2020-01-17 16:47:29.972] [jointLog] [info] Loading pufferfish index
# [2020-01-17 16:47:29.973] [jointLog] [info] Loading dense pufferfish index.
# [2020-01-17 16:47:29.973] [jointLog] [info] done
# [2020-01-17 16:47:29.973] [jointLog] [info] Index contained 1 targets
# [2020-01-17 16:47:29.973] [jointLog] [info] Number of decoys : 0
# [2020-01-17 16:47:29.973] [jointLog] [info] First decoy index : 18,446,744,073,709,551,615
#
#
#
#
#
#
#
#
# [2020-01-17 16:47:30.015] [jointLog] [info] Computed 1 rich equivalence classes for further processing
# [2020-01-17 16:47:30.015] [jointLog] [info] Counted 2,058 total reads in the equivalence classes
# [2020-01-17 16:47:30.016] [jointLog] [info] Number of mappings discarded because of alignment score : 1,540
# [2020-01-17 16:47:30.016] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 874
# [2020-01-17 16:47:30.016] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2020-01-17 16:47:30.016] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 1,037
# [2020-01-17 16:47:30.016] [jointLog] [warning] Only 2058 fragments were mapped, but the number of burn-in fragments was set to 5000000.
# The effective lengths have been computed using the observed mappings.
#
# [2020-01-17 16:47:30.016] [jointLog] [info] Mapping rate = 70.0715%
#
# [2020-01-17 16:47:30.016] [jointLog] [info] finished quantifyLibrary()
# [2020-01-17 16:47:30.016] [jointLog] [info] Starting optimizer
# [2020-01-17 16:47:30.016] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2020-01-17 16:47:30.016] [jointLog] [info] iteration = 0 | max rel diff. = 2.20966e-16
# [2020-01-17 16:47:30.016] [jointLog] [info] iteration = 100 | max rel diff. = 0
# [2020-01-17 16:47:30.016] [jointLog] [info] Finished optimizer
# [2020-01-17 16:47:30.016] [jointLog] [info] writing output
#
# [2020-01-17 16:47:30.016] [jointLog] [warning] NOTE: Read Lib [[ ./data/ggal/ggal_gut_1.fq, ./data/ggal/ggal_gut_2.fq]] :
#
# Detected a *potential* strand bias > 1% in an unstranded protocol check the file: results_salmon/lib_format_counts.json for details

# %%
if not os.path.exists("results_fastqc"):
    os.makedirs("results_fastqc")
    
# !fastqc -o results_fastqc -f fastq -q ./data/ggal/ggal_gut_*.fq

# %%
if not os.path.exists("multiqc_in"):
    os.makedirs("multiqc_in")

if not os.path.exists("results_multiqc"):
    os.makedirs("results_multiqc")

# !cp results_fastqc/* multiqc_in
# !cp -rf results_salmon/* multiqc_in
# !cp multiqc/* multiqc_in
# !echo "custom_logo: $PWD/multiqc_in/logo.png" >> multiqc_in/multiqc_config.yaml

pwd = os.getcwd()
work_dir = pwd + "/multiqc_in"
os.chdir(work_dir)
os.getcwd()

# !multiqc -v . --outdir ../results_multiqc/
# Out:
# /home/jespinosa/conda_env/nxf/rnaseq-nf-58fed063cfbc6adc6b42861c7e7fae6d/lib/python3.6/site-packages/multiqc/utils/config.py:45: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   configs = yaml.load(f)
# /home/jespinosa/conda_env/nxf/rnaseq-nf-58fed063cfbc6adc6b42861c7e7fae6d/lib/python3.6/site-packages/multiqc/utils/config.py:51: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   sp = yaml.load(f)
# [2020-01-17 16:47:41,548] multiqc                                            [DEBUG  ]  No MultiQC config found: /home/jespinosa/conda_env/nxf/rnaseq-nf-58fed063cfbc6adc6b42861c7e7fae6d/lib/python3.6/site-packages/multiqc_config.yaml
# [2020-01-17 16:47:41,548] multiqc                                            [DEBUG  ]  No MultiQC config found: /home/jespinosa/.multiqc_config.yaml
# /home/jespinosa/conda_env/nxf/rnaseq-nf-58fed063cfbc6adc6b42861c7e7fae6d/lib/python3.6/site-packages/multiqc/utils/config.py:121: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   new_config = yaml.load(f)
# [2020-01-17 16:47:41,549] multiqc                                            [DEBUG  ]  Loading config settings from: multiqc_config.yaml
# [2020-01-17 16:47:41,549] multiqc                                            [DEBUG  ]  New config 'title': BovReg template for reproducible analysis
# [2020-01-17 16:47:41,549] multiqc                                            [DEBUG  ]  New config 'subtitle': Nextflow RNA-seq demo - A pipeline for quantification of genomic features from short read data
# [2020-01-17 16:47:41,549] multiqc                                            [DEBUG  ]  New config 'report_header_info': [{'Contact E-mail': 'Bovreg-wp3@ebi.ac.uk'}, {'Application Type': 'RNA-seq'}, {'Project Type': 'BovReg WP3 template'}]
# [2020-01-17 16:47:41,550] multiqc                                            [DEBUG  ]  New config 'custom_logo_url':  https://www.bovreg.eu
# [2020-01-17 16:47:41,550] multiqc                                            [DEBUG  ]  New config 'custom_logo_title': BovReg
# [2020-01-17 16:47:41,550] multiqc                                            [DEBUG  ]  New config 'custom_logo': /home/jespinosa/git/BovReg-Reproducibility/rnaseq-nf/multiqc_in/logo.png
# [2020-01-17 16:47:41,550] multiqc                                            [DEBUG  ]  Command used: /home/jespinosa/conda_env/nxf/rnaseq-nf-58fed063cfbc6adc6b42861c7e7fae6d/bin/multiqc -v . --outdir ../results_multiqc/
# [2020-01-17 16:47:41,948] multiqc                                            [WARNING]  MultiQC Version v1.8 now available!
# [2020-01-17 16:47:41,948] multiqc                                            [INFO   ]  This is MultiQC v1.5.dev0
# [2020-01-17 16:47:41,948] multiqc                                            [DEBUG  ]  Command     : /home/jespinosa/conda_env/nxf/rnaseq-nf-58fed063cfbc6adc6b42861c7e7fae6d/bin/multiqc -v . --outdir ../results_multiqc/
# [2020-01-17 16:47:41,948] multiqc                                            [DEBUG  ]  Working dir : /home/jespinosa/git/BovReg-Reproducibility/rnaseq-nf/multiqc_in
# [2020-01-17 16:47:41,949] multiqc                                            [INFO   ]  Template    : default
# [2020-01-17 16:47:41,949] multiqc                                            [INFO   ]  Report title: BovReg template for reproducible analysis
# [2020-01-17 16:47:41,949] multiqc                                            [INFO   ]  Searching '.'
# [2020-01-17 16:47:41,950] multiqc                                            [DEBUG  ]  Analysing modules: afterqc, custom_content, conpair, peddy, methylQA, qualimap, preseq, quast, qorts, rna_seqc, rsem, rseqc, busco, goleft_indexcov, disambiguate, supernova, deeptools, sargasso, verifybamid, homer, macs2, theta2, snpeff, gatk, htseq, bcftools, featureCounts, picard, prokka, samblaster, samtools, bamtools, jellyfish, vcftools, bbmap, bismark, hicexplorer, hicup, salmon, kallisto, slamdunk, star, hisat2, tophat, bowtie2, bowtie1, leehom, adapterRemoval, cutadapt, flexbar, trimmomatic, skewer, sortmerna, biobloomtools, fastq_screen, fastqc, clusterflow, bcl2fastq, interop
# [2020-01-17 16:47:41,950] multiqc                                            [DEBUG  ]  Using temporary directory for creating report: /tmp/tmpg968djww
# [2020-01-17 16:47:42,039] multiqc                                            [DEBUG  ]  Ignoring file as matched an ignore pattern: ggal_gut_1_fastqc.html
# [2020-01-17 16:47:42,039] multiqc                                            [DEBUG  ]  Ignoring file as matched an ignore pattern: ggal_gut_2_fastqc.html
# [2020-01-17 16:47:42,192] multiqc                                            [DEBUG  ]  No samples found: afterqc
# [2020-01-17 16:47:42,194] multiqc                                            [DEBUG  ]  No samples found: custom_content
# [2020-01-17 16:47:42,196] multiqc                                            [DEBUG  ]  No samples found: conpair
# [2020-01-17 16:47:42,198] multiqc                                            [DEBUG  ]  No samples found: peddy
# [2020-01-17 16:47:42,200] multiqc                                            [DEBUG  ]  No samples found: methylQA
# [2020-01-17 16:47:42,202] multiqc                                            [DEBUG  ]  No samples found: qualimap
# [2020-01-17 16:47:42,203] multiqc                                            [DEBUG  ]  No samples found: preseq
# [2020-01-17 16:47:42,205] multiqc                                            [DEBUG  ]  No samples found: quast
# [2020-01-17 16:47:42,208] multiqc                                            [DEBUG  ]  No samples found: qorts
# [2020-01-17 16:47:42,210] multiqc                                            [DEBUG  ]  No samples found: rna_seqc
# [2020-01-17 16:47:42,212] multiqc                                            [DEBUG  ]  No samples found: rsem
# [2020-01-17 16:47:42,215] multiqc                                            [DEBUG  ]  No samples found: rseqc
# [2020-01-17 16:47:42,216] multiqc                                            [DEBUG  ]  No samples found: busco
# [2020-01-17 16:47:42,218] multiqc                                            [DEBUG  ]  No samples found: goleft_indexcov
# [2020-01-17 16:47:42,220] multiqc                                            [DEBUG  ]  No samples found: disambiguate
# [2020-01-17 16:47:42,222] multiqc                                            [DEBUG  ]  No samples found: supernova
# [2020-01-17 16:47:42,224] multiqc                                            [DEBUG  ]  No samples found: deeptools
# [2020-01-17 16:47:42,226] multiqc                                            [DEBUG  ]  No samples found: sargasso
# [2020-01-17 16:47:42,228] multiqc                                            [DEBUG  ]  No samples found: verifybamid
# [2020-01-17 16:47:42,230] multiqc                                            [DEBUG  ]  No samples found: homer
# [2020-01-17 16:47:42,232] multiqc                                            [DEBUG  ]  No samples found: macs2
# [2020-01-17 16:47:42,233] multiqc                                            [DEBUG  ]  No samples found: theta2
# [2020-01-17 16:47:42,235] multiqc                                            [DEBUG  ]  No samples found: snpeff
# [2020-01-17 16:47:42,237] multiqc                                            [DEBUG  ]  No samples found: gatk
# [2020-01-17 16:47:42,239] multiqc                                            [DEBUG  ]  No samples found: htseq
# [2020-01-17 16:47:42,241] multiqc                                            [DEBUG  ]  No samples found: bcftools
# [2020-01-17 16:47:42,243] multiqc                                            [DEBUG  ]  No samples found: featureCounts
# [2020-01-17 16:47:42,246] multiqc                                            [DEBUG  ]  No samples found: picard
# [2020-01-17 16:47:42,248] multiqc                                            [DEBUG  ]  No samples found: prokka
# [2020-01-17 16:47:42,250] multiqc                                            [DEBUG  ]  No samples found: samblaster
# [2020-01-17 16:47:42,252] multiqc                                            [DEBUG  ]  No samples found: samtools
# [2020-01-17 16:47:42,254] multiqc                                            [DEBUG  ]  No samples found: bamtools
# [2020-01-17 16:47:42,256] multiqc                                            [DEBUG  ]  No samples found: jellyfish
# [2020-01-17 16:47:42,258] multiqc                                            [DEBUG  ]  No samples found: vcftools
# [2020-01-17 16:47:42,261] multiqc                                            [DEBUG  ]  No samples found: bbmap
# [2020-01-17 16:47:42,263] multiqc                                            [DEBUG  ]  No samples found: bismark
# [2020-01-17 16:47:42,265] multiqc                                            [DEBUG  ]  No samples found: hicexplorer
# [2020-01-17 16:47:42,267] multiqc                                            [DEBUG  ]  No samples found: hicup
# [2020-01-17 16:47:42,270] multiqc.modules.salmon.salmon                      [INFO   ]  Found 1 meta reports
# [2020-01-17 16:47:42,270] multiqc.modules.salmon.salmon                      [INFO   ]  Found 1 fragment length distributions
# [2020-01-17 16:47:42,274] multiqc                                            [DEBUG  ]  No samples found: kallisto
# [2020-01-17 16:47:42,275] multiqc                                            [DEBUG  ]  No samples found: slamdunk
# [2020-01-17 16:47:42,277] multiqc                                            [DEBUG  ]  No samples found: star
# [2020-01-17 16:47:42,279] multiqc                                            [DEBUG  ]  No samples found: hisat2
# [2020-01-17 16:47:42,281] multiqc                                            [DEBUG  ]  No samples found: tophat
# [2020-01-17 16:47:42,282] multiqc                                            [DEBUG  ]  No samples found: bowtie2
# [2020-01-17 16:47:42,284] multiqc                                            [DEBUG  ]  No samples found: bowtie1
# [2020-01-17 16:47:42,286] multiqc                                            [DEBUG  ]  No samples found: leehom
# [2020-01-17 16:47:42,288] multiqc                                            [DEBUG  ]  No samples found: adapterRemoval
# [2020-01-17 16:47:42,290] multiqc                                            [DEBUG  ]  No samples found: cutadapt
# [2020-01-17 16:47:42,292] multiqc                                            [DEBUG  ]  No samples found: flexbar
# [2020-01-17 16:47:42,293] multiqc                                            [DEBUG  ]  No samples found: trimmomatic
# [2020-01-17 16:47:42,295] multiqc                                            [DEBUG  ]  No samples found: skewer
# [2020-01-17 16:47:42,297] multiqc                                            [DEBUG  ]  No samples found: sortmerna
# [2020-01-17 16:47:42,299] multiqc                                            [DEBUG  ]  No samples found: biobloomtools
# [2020-01-17 16:47:42,301] multiqc                                            [DEBUG  ]  No samples found: fastq_screen
# [2020-01-17 16:47:42,306] multiqc.modules.fastqc.fastqc                      [INFO   ]  Found 2 reports
# [2020-01-17 16:47:42,331] multiqc                                            [DEBUG  ]  No samples found: clusterflow
# [2020-01-17 16:47:42,332] multiqc                                            [DEBUG  ]  No samples found: bcl2fastq
# [2020-01-17 16:47:42,334] multiqc                                            [DEBUG  ]  No samples found: interop
# [2020-01-17 16:47:42,337] multiqc                                            [INFO   ]  Compressing plot data
# [2020-01-17 16:47:42,365] multiqc                                            [WARNING]  Previous MultiQC output found! Adjusting filenames..
# [2020-01-17 16:47:42,365] multiqc                                            [WARNING]  Use -f or --force to overwrite existing reports instead
# [2020-01-17 16:47:42,365] multiqc                                            [INFO   ]  Report      : ../results_multiqc/multiqc_report_2.html
# [2020-01-17 16:47:42,365] multiqc                                            [INFO   ]  Data        : ../results_multiqc/multiqc_data_2
# [2020-01-17 16:47:42,365] multiqc                                            [DEBUG  ]  Moving data file from '/tmp/tmpg968djww/multiqc_data/multiqc_salmon.txt' to '../results_multiqc/multiqc_data_2'
# [2020-01-17 16:47:42,365] multiqc                                            [DEBUG  ]  Moving data file from '/tmp/tmpg968djww/multiqc_data/multiqc_fastqc.txt' to '../results_multiqc/multiqc_data_2'
# [2020-01-17 16:47:42,365] multiqc                                            [DEBUG  ]  Moving data file from '/tmp/tmpg968djww/multiqc_data/multiqc_sources.txt' to '../results_multiqc/multiqc_data_2'
# [2020-01-17 16:47:42,365] multiqc                                            [DEBUG  ]  Moving data file from '/tmp/tmpg968djww/multiqc_data/multiqc_data.json' to '../results_multiqc/multiqc_data_2'
# [2020-01-17 16:47:42,365] multiqc                                            [DEBUG  ]  Moving data file from '/tmp/tmpg968djww/multiqc_data/multiqc_general_stats.txt' to '../results_multiqc/multiqc_data_2'
# [2020-01-17 16:47:42,428] multiqc                                            [INFO   ]  MultiQC complete

# %%
shutil.rmtree(work_dir)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/jespinosa/conda_env/nxf/rnaseq-nf-58fed063cfbc6adc6b42861c7e7fae6d/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3319, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-8c01a606a94a>", line 1, in <module>
#     shutil.rmtree(work_dir)
#   File "/home/jespinosa/conda_env/nxf/rnaseq-nf-58fed063cfbc6adc6b42861c7e7fae6d/lib/python3.6/shutil.py", line 477, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/home/jespinosa/conda_env/nxf/rnaseq-nf-58fed063cfbc6adc6b42861c7e7fae6d/lib/python3.6/shutil.py", line 475, in rmtree
#     orig_st = os.lstat(path)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jespinosa/git/BovReg-Reproducibility/rnaseq-nf/multiqc_in'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jespinosa/conda_env/nxf/rnaseq-nf-58fed063cfbc6adc6b42861c7e7fae6d/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2034, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'FileNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jespinosa/conda_env/nxf/rnaseq-nf-58fed063cfbc6adc6b42861c7e7fae6d/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1151, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/jespinosa/conda_env/nxf/rnaseq-nf-58fed063cfbc6adc6b42861c7e7fae6d/lib/python3.6/site-packages/IPython/core/ultratb.py", line 319, in wrapped
#     return f(*args, **kwargs)
#   File "/home/jespinosa/conda_env/nxf/rnaseq-nf-58fed063cfbc6adc6b42861c7e7fae6d/lib/python3.6/site-packages/IPython/core/ultratb.py", line 353, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/jespinosa/conda_env/nxf/rnaseq-nf-58fed063cfbc6adc6b42861c7e7fae6d/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/jespinosa/conda_env/nxf/rnaseq-nf-58fed063cfbc6adc6b42861c7e7fae6d/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/jespinosa/conda_env/nxf/rnaseq-nf-58fed063cfbc6adc6b42861c7e7fae6d/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/jespinosa/conda_env/nxf/rnaseq-nf-58fed063cfbc6adc6b42861c7e7fae6d/lib/python3.6/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/home/jespinosa/conda_env/nxf/rnaseq-nf-58fed063cfbc6adc6b42861c7e7fae6d/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/home/jespinosa/conda_env/nxf/rnaseq-nf-58fed063cfbc6adc6b42861c7e7fae6d/lib/python3.6/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
# ---------------------------------------------------------------------------

# %%
work_dir
