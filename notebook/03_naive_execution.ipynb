# %%
# Run pipeline with bash (You will need to install salmon, fastQC and multiQC first)

# %%
import os
pwd = os.getcwd()
os.getcwd()
pipeline_folder = "rnaseq-nf" 
work_dir = pwd + "/../" + pipeline_folder
os.chdir(work_dir)
os.getcwd()
# Out:
# '/home/kadomu/git/BovReg-Reproducibility/rnaseq-nf'

# %%
# !salmon index --threads 1 -t ./data/ggal/ggal_1_48850000_49020000.Ggal71.500bpflank.fa -i index
# Out:
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# index ["index"] did not previously exist  . . . creating it
# [2020-01-16 15:51:16.105] [jLog] [info] building index
# out : index
# [2020-01-16 15:51:16.105] [puff::index::jointLog] [info] Running fixFasta
#
# [Step 1 of 4] : counting k-mers
#
# [2020-01-16 15:51:16.122] [puff::index::jointLog] [info] Replaced 0 non-ATCG nucleotides
# [2020-01-16 15:51:16.122] [puff::index::jointLog] [info] Clipped poly-A tails from 0 transcripts
# wrote 1 cleaned references
# seqHash 256 : c7b06752fa0748ecfa05ab97e8460b69c408b6d5fedf9de3d0d53b05570cf942
# seqHash 512 : ed859a805ddc0e6805be16dea7160060c1ecf1853f01fe24e64779390dd0b4aa157dab4d3e6234e9f7a1a80cd74df05454259b325624f601a0f86ea508550a8e
# nameHash 256 : 6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d49c01e52ddb7875b4b
# nameHash 512 : 4dff4ea340f0a823f15d3f4f01ab62eae0e5da579ccb851f8db9dfe84c58b2b37b89903a740e1ee172da793a6e79d560e5f7f9bd058a12a280433ed6fa46510a
# [2020-01-16 15:51:16.124] [puff::index::jointLog] [info] Filter size not provided; estimating from number of distinct k-mers
# [2020-01-16 15:51:16.135] [puff::index::jointLog] [info] ntHll estimated 147846 distinct k-mers, setting filter size to 2^22
# Threads = 1
# Vertex length = 31
# Hash functions = 5
# Filter size = 4194304
# Capacity = 2
# Files:
# index/ref_k31_fixed.fa
# --------------------------------------------------------------------------------
# Round 0, 0:4194304
# Pass	Filling	Filtering
# 1	0	0
# 2	0	0
# True junctions count = 7
# False junctions count = 223
# Hash table size = 230
# Candidate marks count = 237
# --------------------------------------------------------------------------------
# Reallocating bifurcations time: 0
# True marks count: 16
# Edges construction time: 0
# --------------------------------------------------------------------------------
# Distinct junctions = 7
#
# approximateContigTotalLength: 92130
# counters:
# 1 0 0 0
# contig count: 14 element count: 171333 complex nodes: 1
# size: 171333
# # of ones in rank vector: 13
# size: 171333
# [2020-01-16 15:51:16.420] [puff::index::jointLog] [info] Setting the index/BinaryGfa directory index
# size = 171333
# -----------------------------------------
# | Loading contigs | Time = 35.755 us
# -----------------------------------------
# size = 171333
# -----------------------------------------
# | Loading contig boundaries | Time = 16.034 us
# -----------------------------------------
# Number of ones: 13
# Number of ones per inventory item: 512
# Inventory entries filled: 1
# [2020-01-16 15:51:16.421] [puff::index::jointLog] [info] Done wrapping the rank vector with a rank9sel structure.
# [2020-01-16 15:51:16.421] [puff::index::jointLog] [info] contig count for validation: 13
# [2020-01-16 15:51:16.421] [puff::index::jointLog] [info] Total # of Contigs : 13
# [2020-01-16 15:51:16.421] [puff::index::jointLog] [info] Total # of numerical Contigs : 13
# [2020-01-16 15:51:16.421] [puff::index::jointLog] [info]
# Total # of segments we have position for : 13
# [2020-01-16 15:51:16.421] [puff::index::jointLog] [info] total contig vec entries 17
# [2020-01-16 15:51:16.421] [puff::index::jointLog] [info] bits per offset entry 5
# [2020-01-16 15:51:16.421] [puff::index::jointLog] [info] there were 1  equivalence classes
# [2020-01-16 15:51:16.421] [puff::index::jointLog] [info] # segments = 13
# [2020-01-16 15:51:16.421] [puff::index::jointLog] [info] total length = 171,333
# [2020-01-16 15:51:16.421] [puff::index::jointLog] [info] Reading the reference files ...
# [2020-01-16 15:51:16.423] [puff::index::jointLog] [info] positional integer width = 18
# [2020-01-16 15:51:16.423] [puff::index::jointLog] [info] seqSize = 171,333
# [2020-01-16 15:51:16.423] [puff::index::jointLog] [info] rankSize = 171,333
# [2020-01-16 15:51:16.423] [puff::index::jointLog] [info] edgeVecSize = 0
# [2020-01-16 15:51:16.423] [puff::index::jointLog] [info] num keys = 170,943
# for info, total work write each  : 2.331    total work inram from level 3 : 4.322  total work raw : 25.000
# [Building BooPHF]  100  %   elapsed:   0 min 0  sec   remaining:   0 min 0  sec
# Bitarray          901696  bits (100.00 %)   (array + ranks )
# final hash             0  bits (0.00 %) (nb in final hash 0)
# [2020-01-16 15:51:16.462] [puff::index::jointLog] [info] mphf size = 0.107491 MB
# [2020-01-16 15:51:16.462] [puff::index::jointLog] [info] chunk size = 171,333
# [2020-01-16 15:51:16.462] [puff::index::jointLog] [info] chunk 0 = [0, 171,303)
# [2020-01-16 15:51:16.484] [puff::index::jointLog] [info] finished populating pos vector
# [2020-01-16 15:51:16.484] [puff::index::jointLog] [info] writing index components
# [2020-01-16 15:51:16.485] [puff::index::jointLog] [info] finished writing dense pufferfish index
# [2020-01-16 15:51:16.485] [jLog] [info] done building index

# %%
# !salmon quant --threads 1 --libType=U -i index -1 ./data/ggal/ggal_gut_1.fq -2 ./data/ggal/ggal_gut_2.fq  -o results_salmon
# Out:
# Version Info: ### PLEASE UPGRADE SALMON ###
# ### A newer version of salmon with important bug fixes and improvements is available. ####
# ###
# The newest version, available at https://github.com/COMBINE-lab/salmon/releases
# contains new features, improvements, and bug fixes; please upgrade at your
# earliest convenience.
# ###
# Sign up for the salmon mailing list to hear about new versions, features and updates at:
# https://oceangenomics.com/subscribe
# ###
# ### salmon (mapping-based) v1.0.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ threads ] => { 1 }
# ### [ libType ] => { U }
# ### [ index ] => { index }
# ### [ mates1 ] => { ./data/ggal/ggal_gut_1.fq }
# ### [ mates2 ] => { ./data/ggal/ggal_gut_2.fq }
# ### [ output ] => { results_salmon }
# Logs will be written to results_salmon/logs
# [2020-01-16 18:03:43.521] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2020-01-16 18:03:43.521] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2020-01-16 18:03:43.521] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2020-01-16 18:03:43.521] [jointLog] [info] parsing read library format
# [2020-01-16 18:03:43.521] [jointLog] [info] There is 1 library.
# -----------------------------------------
# | Loading contig table | Time = 18.012 us
# -----------------------------------------
# size = 14
# -----------------------------------------
# | Loading contig offsets | Time = 24.271 us
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 7.011 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 114.29 us
# -----------------------------------------
# size = 171333
# Number of ones: 13
# Number of ones per inventory item: 512
# Inventory entries filled: 1
# -----------------------------------------
# | Loading contig boundaries | Time = 516.7 us
# -----------------------------------------
# size = 171333
# -----------------------------------------
# | Loading sequence | Time = 43.691 us
# -----------------------------------------
# size = 170943
# -----------------------------------------
# | Loading positions | Time = 111.57 us
# -----------------------------------------
# size = 171001
# -----------------------------------------
# | Loading reference sequence | Time = 46.674 us
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 7.838 us
# -----------------------------------------
# [2020-01-16 18:03:43.633] [jointLog] [info] Loading pufferfish index
# [2020-01-16 18:03:43.633] [jointLog] [info] Loading dense pufferfish index.
# [2020-01-16 18:03:43.634] [jointLog] [info] done
# [2020-01-16 18:03:43.634] [jointLog] [info] Index contained 1 targets
# [2020-01-16 18:03:43.634] [jointLog] [info] Number of decoys : 0
# [2020-01-16 18:03:43.634] [jointLog] [info] First decoy index : 18,446,744,073,709,551,615
#
#
#
#
#
#
#
#
#
#
#
#
# [2020-01-16 18:03:43.753] [jointLog] [info] Computed 1 rich equivalence classes for further processing
# [2020-01-16 18:03:43.753] [jointLog] [info] Counted 2,058 total reads in the equivalence classes
# [2020-01-16 18:03:43.754] [jointLog] [info] Number of mappings discarded because of alignment score : 1,540
# [2020-01-16 18:03:43.754] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 874
# [2020-01-16 18:03:43.754] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2020-01-16 18:03:43.754] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 1,037
# [2020-01-16 18:03:43.755] [jointLog] [warning] Only 2058 fragments were mapped, but the number of burn-in fragments was set to 5000000.
# The effective lengths have been computed using the observed mappings.
#
# [2020-01-16 18:03:43.755] [jointLog] [info] Mapping rate = 70.0715%
#
# [2020-01-16 18:03:43.755] [jointLog] [info] finished quantifyLibrary()
# [2020-01-16 18:03:43.755] [jointLog] [info] Starting optimizer
# [2020-01-16 18:03:43.755] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2020-01-16 18:03:43.756] [jointLog] [info] iteration = 0 | max rel diff. = 2.20966e-16
# [2020-01-16 18:03:43.756] [jointLog] [info] iteration = 100 | max rel diff. = 0
# [2020-01-16 18:03:43.756] [jointLog] [info] Finished optimizer
# [2020-01-16 18:03:43.756] [jointLog] [info] writing output
#
# [2020-01-16 18:03:43.756] [jointLog] [warning] NOTE: Read Lib [[ ./data/ggal/ggal_gut_1.fq, ./data/ggal/ggal_gut_2.fq]] :
#
# Detected a *potential* strand bias > 1% in an unstranded protocol check the file: results_salmon/lib_format_counts.json for details

# %%
if not os.path.exists("results_fastqc"):
    os.makedirs("results_fastqc")
    
# !fastqc -o results_fastqc -f fastq -q ./data/ggal/ggal_gut_*.fq

# %%
if not os.path.exists("multiqc_in"):
    os.makedirs("multiqc_in")

if not os.path.exists("results_multiqc"):
    os.makedirs("results_multiqc")

# !cp results_fastqc/* multiqc_in
# !cp -rf results_salmon/* multiqc_in
# !cp multiqc/* multiqc_in
# !echo "custom_logo: $PWD/multiqc_in/logo.png" >> multiqc_in/multiqc_config.yaml

pwd = os.getcwd()
work_dir = pwd + "/multiqc_in"
os.chdir(work_dir)
os.getcwd()

# !multiqc -v .
# Out:
# /home/kadomu/conda_env_nxf/rnaseq-nf-58fed063cfbc6adc6b42861c7e7fae6d/lib/python3.6/site-packages/multiqc/utils/config.py:45: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   configs = yaml.load(f)
# /home/kadomu/conda_env_nxf/rnaseq-nf-58fed063cfbc6adc6b42861c7e7fae6d/lib/python3.6/site-packages/multiqc/utils/config.py:51: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   sp = yaml.load(f)
# [2020-01-16 18:57:39,096] multiqc                                            [DEBUG  ]  No MultiQC config found: /home/kadomu/conda_env_nxf/rnaseq-nf-58fed063cfbc6adc6b42861c7e7fae6d/lib/python3.6/site-packages/multiqc_config.yaml
# [2020-01-16 18:57:39,096] multiqc                                            [DEBUG  ]  No MultiQC config found: /home/kadomu/.multiqc_config.yaml
# /home/kadomu/conda_env_nxf/rnaseq-nf-58fed063cfbc6adc6b42861c7e7fae6d/lib/python3.6/site-packages/multiqc/utils/config.py:121: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   new_config = yaml.load(f)
# [2020-01-16 18:57:39,099] multiqc                                            [DEBUG  ]  Loading config settings from: multiqc_config.yaml
# [2020-01-16 18:57:39,099] multiqc                                            [DEBUG  ]  New config 'title': BovReg template for reproducible analysis
# [2020-01-16 18:57:39,100] multiqc                                            [DEBUG  ]  New config 'subtitle': Nextflow RNA-seq demo - A pipeline for quantification of genomic features from short read data
# [2020-01-16 18:57:39,100] multiqc                                            [DEBUG  ]  New config 'report_header_info': [{'Contact E-mail': 'Bovreg-wp3@ebi.ac.uk'}, {'Application Type': 'RNA-seq'}, {'Project Type': 'BovReg WP3 template'}]
# [2020-01-16 18:57:39,100] multiqc                                            [DEBUG  ]  New config 'custom_logo_url':  https://www.bovreg.eu
# [2020-01-16 18:57:39,100] multiqc                                            [DEBUG  ]  New config 'custom_logo_title': BovReg
# [2020-01-16 18:57:39,100] multiqc                                            [DEBUG  ]  New config 'custom_logo': /home/kadomu/git/BovReg-Reproducibility/rnaseq-nf/multiqc_in/logo.png
# [2020-01-16 18:57:39,100] multiqc                                            [DEBUG  ]  Command used: /home/kadomu/conda_env_nxf/rnaseq-nf-58fed063cfbc6adc6b42861c7e7fae6d/bin/multiqc -v .
# [2020-01-16 18:57:39,756] multiqc                                            [WARNING]  MultiQC Version v1.8 now available!
# [2020-01-16 18:57:39,757] multiqc                                            [INFO   ]  This is MultiQC v1.5.dev0
# [2020-01-16 18:57:39,757] multiqc                                            [DEBUG  ]  Command     : /home/kadomu/conda_env_nxf/rnaseq-nf-58fed063cfbc6adc6b42861c7e7fae6d/bin/multiqc -v .
# [2020-01-16 18:57:39,757] multiqc                                            [DEBUG  ]  Working dir : /home/kadomu/git/BovReg-Reproducibility/rnaseq-nf/multiqc_in
# [2020-01-16 18:57:39,758] multiqc                                            [INFO   ]  Template    : default
# [2020-01-16 18:57:39,758] multiqc                                            [INFO   ]  Report title: BovReg template for reproducible analysis
# [2020-01-16 18:57:39,758] multiqc                                            [INFO   ]  Searching '.'
# [2020-01-16 18:57:39,759] multiqc                                            [DEBUG  ]  Analysing modules: afterqc, custom_content, conpair, peddy, methylQA, qualimap, preseq, quast, qorts, rna_seqc, rsem, rseqc, busco, goleft_indexcov, disambiguate, supernova, deeptools, sargasso, verifybamid, homer, macs2, theta2, snpeff, gatk, htseq, bcftools, featureCounts, picard, prokka, samblaster, samtools, bamtools, jellyfish, vcftools, bbmap, bismark, hicexplorer, hicup, salmon, kallisto, slamdunk, star, hisat2, tophat, bowtie2, bowtie1, leehom, adapterRemoval, cutadapt, flexbar, trimmomatic, skewer, sortmerna, biobloomtools, fastq_screen, fastqc, clusterflow, bcl2fastq, interop
# [2020-01-16 18:57:39,759] multiqc                                            [DEBUG  ]  Using temporary directory for creating report: /tmp/tmpj1lkv0xe
# [2020-01-16 18:57:39,980] multiqc                                            [DEBUG  ]  Ignoring directory as matched fn_ignore_dirs: ./multiqc_data
# [2020-01-16 18:57:39,986] multiqc                                            [DEBUG  ]  Ignoring file as matched an ignore pattern: ggal_gut_1_fastqc.html
# [2020-01-16 18:57:40,023] multiqc                                            [DEBUG  ]  Ignoring file as matched an ignore pattern: ggal_gut_2_fastqc.html
# [2020-01-16 18:57:40,024] multiqc                                            [DEBUG  ]  Ignoring file as matched an ignore pattern: multiqc_report.html
# [2020-01-16 18:57:40,362] multiqc                                            [DEBUG  ]  No samples found: afterqc
# [2020-01-16 18:57:40,368] multiqc                                            [DEBUG  ]  No samples found: custom_content
# [2020-01-16 18:57:40,375] multiqc                                            [DEBUG  ]  No samples found: conpair
# [2020-01-16 18:57:40,380] multiqc                                            [DEBUG  ]  No samples found: peddy
# [2020-01-16 18:57:40,385] multiqc                                            [DEBUG  ]  No samples found: methylQA
# [2020-01-16 18:57:40,390] multiqc                                            [DEBUG  ]  No samples found: qualimap
# [2020-01-16 18:57:40,394] multiqc                                            [DEBUG  ]  No samples found: preseq
# [2020-01-16 18:57:40,398] multiqc                                            [DEBUG  ]  No samples found: quast
# [2020-01-16 18:57:40,405] multiqc                                            [DEBUG  ]  No samples found: qorts
# [2020-01-16 18:57:40,409] multiqc                                            [DEBUG  ]  No samples found: rna_seqc
# [2020-01-16 18:57:40,413] multiqc                                            [DEBUG  ]  No samples found: rsem
# [2020-01-16 18:57:40,420] multiqc                                            [DEBUG  ]  No samples found: rseqc
# [2020-01-16 18:57:40,424] multiqc                                            [DEBUG  ]  No samples found: busco
# [2020-01-16 18:57:40,429] multiqc                                            [DEBUG  ]  No samples found: goleft_indexcov
# [2020-01-16 18:57:40,433] multiqc                                            [DEBUG  ]  No samples found: disambiguate
# [2020-01-16 18:57:40,438] multiqc                                            [DEBUG  ]  No samples found: supernova
# [2020-01-16 18:57:40,444] multiqc                                            [DEBUG  ]  No samples found: deeptools
# [2020-01-16 18:57:40,448] multiqc                                            [DEBUG  ]  No samples found: sargasso
# [2020-01-16 18:57:40,452] multiqc                                            [DEBUG  ]  No samples found: verifybamid
# [2020-01-16 18:57:40,457] multiqc                                            [DEBUG  ]  No samples found: homer
# [2020-01-16 18:57:40,461] multiqc                                            [DEBUG  ]  No samples found: macs2
# [2020-01-16 18:57:40,465] multiqc                                            [DEBUG  ]  No samples found: theta2
# [2020-01-16 18:57:40,470] multiqc                                            [DEBUG  ]  No samples found: snpeff
# [2020-01-16 18:57:40,475] multiqc                                            [DEBUG  ]  No samples found: gatk
# [2020-01-16 18:57:40,481] multiqc                                            [DEBUG  ]  No samples found: htseq
# [2020-01-16 18:57:40,485] multiqc                                            [DEBUG  ]  No samples found: bcftools
# [2020-01-16 18:57:40,490] multiqc                                            [DEBUG  ]  No samples found: featureCounts
# [2020-01-16 18:57:40,498] multiqc                                            [DEBUG  ]  No samples found: picard
# [2020-01-16 18:57:40,502] multiqc                                            [DEBUG  ]  No samples found: prokka
# [2020-01-16 18:57:40,506] multiqc                                            [DEBUG  ]  No samples found: samblaster
# [2020-01-16 18:57:40,512] multiqc                                            [DEBUG  ]  No samples found: samtools
# [2020-01-16 18:57:40,516] multiqc                                            [DEBUG  ]  No samples found: bamtools
# [2020-01-16 18:57:40,520] multiqc                                            [DEBUG  ]  No samples found: jellyfish
# [2020-01-16 18:57:40,525] multiqc                                            [DEBUG  ]  No samples found: vcftools
# [2020-01-16 18:57:40,535] multiqc                                            [DEBUG  ]  No samples found: bbmap
# [2020-01-16 18:57:40,540] multiqc                                            [DEBUG  ]  No samples found: bismark
# [2020-01-16 18:57:40,544] multiqc                                            [DEBUG  ]  No samples found: hicexplorer
# [2020-01-16 18:57:40,548] multiqc                                            [DEBUG  ]  No samples found: hicup
# [2020-01-16 18:57:40,554] multiqc.modules.salmon.salmon                      [INFO   ]  Found 1 meta reports
# [2020-01-16 18:57:40,554] multiqc.modules.salmon.salmon                      [INFO   ]  Found 1 fragment length distributions
# [2020-01-16 18:57:40,562] multiqc                                            [DEBUG  ]  No samples found: kallisto
# [2020-01-16 18:57:40,567] multiqc                                            [DEBUG  ]  No samples found: slamdunk
# [2020-01-16 18:57:40,571] multiqc                                            [DEBUG  ]  No samples found: star
# [2020-01-16 18:57:40,576] multiqc                                            [DEBUG  ]  No samples found: hisat2
# [2020-01-16 18:57:40,581] multiqc                                            [DEBUG  ]  No samples found: tophat
# [2020-01-16 18:57:40,586] multiqc                                            [DEBUG  ]  No samples found: bowtie2
# [2020-01-16 18:57:40,590] multiqc                                            [DEBUG  ]  No samples found: bowtie1
# [2020-01-16 18:57:40,595] multiqc                                            [DEBUG  ]  No samples found: leehom
# [2020-01-16 18:57:40,601] multiqc                                            [DEBUG  ]  No samples found: adapterRemoval
# [2020-01-16 18:57:40,606] multiqc                                            [DEBUG  ]  No samples found: cutadapt
# [2020-01-16 18:57:40,611] multiqc                                            [DEBUG  ]  No samples found: flexbar
# [2020-01-16 18:57:40,615] multiqc                                            [DEBUG  ]  No samples found: trimmomatic
# [2020-01-16 18:57:40,620] multiqc                                            [DEBUG  ]  No samples found: skewer
# [2020-01-16 18:57:40,627] multiqc                                            [DEBUG  ]  No samples found: sortmerna
# [2020-01-16 18:57:40,632] multiqc                                            [DEBUG  ]  No samples found: biobloomtools
# [2020-01-16 18:57:40,638] multiqc                                            [DEBUG  ]  No samples found: fastq_screen
# [2020-01-16 18:57:40,651] multiqc.modules.fastqc.fastqc                      [INFO   ]  Found 2 reports
# [2020-01-16 18:57:40,709] multiqc                                            [DEBUG  ]  No samples found: clusterflow
# [2020-01-16 18:57:40,713] multiqc                                            [DEBUG  ]  No samples found: bcl2fastq
# [2020-01-16 18:57:40,717] multiqc                                            [DEBUG  ]  No samples found: interop
# [2020-01-16 18:57:40,725] multiqc                                            [INFO   ]  Compressing plot data
# [2020-01-16 18:57:40,791] multiqc                                            [WARNING]  Previous MultiQC output found! Adjusting filenames..
# [2020-01-16 18:57:40,791] multiqc                                            [WARNING]  Use -f or --force to overwrite existing reports instead
# [2020-01-16 18:57:40,791] multiqc                                            [INFO   ]  Report      : multiqc_report_1.html
# [2020-01-16 18:57:40,791] multiqc                                            [INFO   ]  Data        : multiqc_data_1
# [2020-01-16 18:57:40,791] multiqc                                            [DEBUG  ]  Moving data file from '/tmp/tmpj1lkv0xe/multiqc_data/multiqc_fastqc.txt' to '/home/kadomu/git/BovReg-Reproducibility/rnaseq-nf/multiqc_in/multiqc_data_1'
# [2020-01-16 18:57:40,792] multiqc                                            [DEBUG  ]  Moving data file from '/tmp/tmpj1lkv0xe/multiqc_data/multiqc_sources.txt' to '/home/kadomu/git/BovReg-Reproducibility/rnaseq-nf/multiqc_in/multiqc_data_1'
# [2020-01-16 18:57:40,792] multiqc                                            [DEBUG  ]  Moving data file from '/tmp/tmpj1lkv0xe/multiqc_data/multiqc_general_stats.txt' to '/home/kadomu/git/BovReg-Reproducibility/rnaseq-nf/multiqc_in/multiqc_data_1'
# [2020-01-16 18:57:40,792] multiqc                                            [DEBUG  ]  Moving data file from '/tmp/tmpj1lkv0xe/multiqc_data/multiqc_salmon.txt' to '/home/kadomu/git/BovReg-Reproducibility/rnaseq-nf/multiqc_in/multiqc_data_1'
# [2020-01-16 18:57:40,792] multiqc                                            [DEBUG  ]  Moving data file from '/tmp/tmpj1lkv0xe/multiqc_data/multiqc_data.json' to '/home/kadomu/git/BovReg-Reproducibility/rnaseq-nf/multiqc_in/multiqc_data_1'
# [2020-01-16 18:57:40,918] multiqc                                            [INFO   ]  MultiQC complete
